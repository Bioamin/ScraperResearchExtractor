# %%
import requests
from bs4 import BeautifulSoup, Comment
import os
import openai
import re
import ast
import pandas as pd
import time
from tqdm import tqdm
from transformers import GPT2Tokenizer

tokenizer = GPT2Tokenizer.from_pretrained('gpt2')  # Initialize tokenizer

# %%
def extract_text_and_urls(url):
    """
    Function to extract the text and URLs from a webpage
    """
    output_string = ""
    try:
        response = requests.get(url)
        response.raise_for_status()  
        soup = BeautifulSoup(response.text, 'html.parser')
        for script in soup(["script", "style"]):
            script.extract()
        for comments in soup.findAll(text=lambda text: isinstance(text, Comment)):
            comments.extract()

        last_string = None
        for tag in soup.recursiveChildGenerator():
            if tag.name == 'a' and tag.get('href'):  
                output_string += tag.get('href') + '\n'
            elif tag.string:
                text = tag.string.strip()  
                if text and text != last_string: 
                    output_string += repr(text) + '\n'
                    last_string = text  

        tokens = tokenizer.encode(output_string)  # Encode the string into tokens
        token_chunks = [tokens[i:i + 3000] for i in range(0, len(tokens), 3000)]  # Group tokens into sets of 4000
        web_strings = [tokenizer.decode(chunk) for chunk in token_chunks]  # Decode each chunk back into a string



    except (requests.RequestException, ValueError):
        print('Invalid URL or unable to make the request')
        return None

    return web_strings  # Return a list of web strings instead of a single string

# %%
def openai_chat_gpt(prompt, text, api_key, model):
    """
    Function to interact with ChatGPT
    """
    openai.api_key = api_key
    message = [
        {"role": "system", "content": text},
        {"role": "user", "content": prompt}
    ]
    response = openai.ChatCompletion.create(
        model=model,
        messages=message,
        organization="org-TTgWchV9zhTLH5bQKcFyPZpF"
    )
    time.sleep(5)
    return response['choices'][0]['message']['content']

# %%
def fetch_institution_name(web_string, api_key, model):
    """
    Function to fetch institution name from given string using OpenAI model
    """
    prompt1 = "Please provide the primary institution name from the following information in a single-item Python list format, without explanation."
    return openai_chat_gpt(prompt1, web_string, api_key, model)

# %%
def fetch_faculty_data(web_strings, api_key, model):
    """
    Function to fetch faculty data from given string using OpenAI model
    """
    prompt2 = "Construct a list named 'faculty_list'. Use the information given to form tuples of four elements: faculty member's name, academic title, research area(s), and URL. If no information is available, return an empty list. For any unknown items, use 'N/A'."
    faculty_string_final = ""
    for text in web_strings:
        faculty_string = openai_chat_gpt(prompt2, text, api_key, model)
        if faculty_string:
            faculty_string_final += faculty_string + " "  
    return faculty_string_final

# %%
def extract_python_lists_from_string(input_string):
    """
    Function to extract python lists from a string
    """
    pattern = re.compile(r'\w+\s*=\s*\[.*?\]', re.DOTALL)
    matches = pattern.findall(input_string)
    combined_list = []
    for match in matches:
        # split each match into separate list assignments
        assignments = match.split('faculty_list = [')
        for assignment in assignments:
            if not assignment:
                continue
            assignment = '[' + assignment  # add the opening bracket back
            try:
                python_list = ast.literal_eval(assignment)
                if isinstance(python_list, list):
                    combined_list.extend(python_list)
            except (ValueError, SyntaxError):
                print(f"Error converting string to list: {assignment}")
    return combined_list

# %%
OPENAI_API_KEY = "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"
MODEL = "gpt-3.5-turbo"
urls = ['https://www.soest.hawaii.edu/oceanography/ocn-people/ocn-faculty/', 
       'https://ceoas.oregonstate.edu/oceanography-faculty']
dfs = []

# %%
#I should also select another windows of tokens to prevent missing any information. 
for url in urls:
    print(f"Processing {url}")
    web_strings = extract_text_and_urls(url)  # Now this returns a list of strings
    institution_name = fetch_institution_name(web_strings[0], OPENAI_API_KEY, MODEL)
    faculty_string_final = fetch_faculty_data(web_strings, OPENAI_API_KEY, MODEL)
    combined_list = extract_python_lists_from_string(faculty_string_final)
    df = pd.DataFrame(combined_list, columns=['PI_Name', 'Academic_title', 'Research_area', 'URL'])
    df['Institution_Name'] = institution_name
    dfs.append(df)
# Out:
# Processing https://www.soest.hawaii.edu/oceanography/ocn-people/ocn-faculty/
# <ipython-input-10-eee4125871f1>:12: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   for comments in soup.findAll(text=lambda text: isinstance(text, Comment)):
# Token indices sequence length is longer than the specified maximum sequence length for this model (4679 > 1024). Running this sequence through the model will result in indexing errors
# Processing https://ceoas.oregonstate.edu/oceanography-faculty
# <ipython-input-10-eee4125871f1>:12: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   for comments in soup.findAll(text=lambda text: isinstance(text, Comment)):

# %%
final_df = pd.concat(dfs, ignore_index=True)
final_df.to_csv('final_dataframe.csv', index=False)
print(final_df)
# Out:
#                   PI_Name                                     Academic_title  \
# 0               Ho, David                                          Professor
# 1           Howell, Steve                               Assistant Researcher
# 2             Karl, David                                          Professor
# 3         Kealoha, Andrea                                Assistant Professor
# 4         Luther, Douglas                                          Professor
# 5       McManus, Margaret                                          Professor
# 6           Nelson, Craig                                          Professor
# 7           Powell, Brian                                          Professor
# 8                 Qiu, Bo                                          Professor
# 9        Richards, Kelvin                                          Professor
# 10   Ruttenberg, Kathleen                                          Professor
# 11    Sabine, Christopher                                          Professor
# 12      Schneider, Niklas                                          Professor
# 13           Selph, Karen                                         Specialist
# 14         Steward, Grieg                                          Professor
# 15        Stuecker, Malte                                Assistant Professor
# 16       Thompson, Philip                                Associate Professor
# 17      White, Angelicque                                          Professor
# 18         Zeebe, Richard                                          Professor
# 19             Jack Barth  Professor, Executive Director of the Marine St...
# 20            Kim Bernard                                Associate Professor
# 21           Rene Boiteau                                Assistant Professor
# 22      Lorenzo Ciannelli                                          Professor
# 23           Rick Colwell                                          Professor
# 24            Byron Crump                                          Professor
# 25        Simon de Szoeke                                          Professor
# 26               Ed Dever                                          Professor
# 27  Jennifer Fehrenbacher                                Assistant Professor
# 28        Melanie Fewings                                Associate Professor
# 29          Jonathan Fram              Associate Professor (Senior Research)
# 30       Chris Goldfinger                                          Professor
# 31            Miguel Goñi                                          Professor
# 32            Burke Hales                                          Professor
# 33         Merrick Haller                                          Professor
# 34          Michael Harte  Professor and Associate Dean for Undergraduate...
# 35        Jenny Hutchings                                Associate Professor
# 36         Laurie Juranek                                Associate Professor
# 37        Maria Kavanaugh                                Assistant Professor
# 38            Jim Lerczak                                          Professor
# 39       Ricardo Letelier                                          Professor
# 40         Jennifer McKay              Assistant Professor (Senior Research)
# 41             James Moum                                          Professor
# 42          Jonathan Nash                                          Professor
# 43          Larry O'Neill                                Associate Professor
# 44      Tuba Özkan-Haller                            Professor, Interim Dean
# 45         Brodie Pearson                                Assistant Professor
# 46          Clare Reimers  Distinguished Professor of Ocean Ecology and B...
# 47         Peter Ruggiero                                          Professor
# 48     Andreas Schmittner                                          Professor
# 49          Kipp Shearman                                          Professor
# 50          Emily Shroyer                                          Professor
# 51          William Smyth                                          Professor
# 52           Yvette Spitz                                          Professor
# 53             Joe Stoner                                          Professor
# 54         Andrew Thurber                                Associate Professor
# 55             Mo Walczak                                Assistant Professor
# 56      George Waldbusser                Professor and Program Head for OEAS
# 57         Rob Wheatcroft                                   Professor Emerit
# 58            Greg Wilson                                Assistant Professor
#
#                                         Research_area  \
# 0                     Marine Geology and Geochemistry
# 1                     Marine Geology and Geochemistry
# 2                             Biological Oceanography
# 3                     Marine Geology and Geochemistry
# 4                               Physical Oceanography
# 5                               Physical Oceanography
# 6                             Biological Oceanography
# 7                               Physical Oceanography
# 8                               Physical Oceanography
# 9                               Physical Oceanography
# 10                    Marine Geology and Geochemistry
# 11                    Marine Geology and Geochemistry
# 12                              Physical Oceanography
# 13                            Biological Oceanography
# 14                            Biological Oceanography
# 15                              Physical Oceanography
# 16                              Physical Oceanography
# 17                            Biological Oceanography
# 18                    Marine Geology and Geochemistry
# 19  Coastal ocean dynamics, coastal marine ecosyst...
# 20                          Polar zooplankton ecology
# 21  Organic biogeochemistry, mass spectrometry, tr...
# 22  Fisheries oceanography, spatial ecology, fish ...
# 23  Microbial ecology, subsurface microbiology, ge...
# 24  Aquatic microbial ecology in marine, estuarine...
# 25  Atmosphere-ocean interaction, stratiform cloud...
# 26  Cross-shelf exchange processes, analysis and p...
# 27                                Tracer oceanography
# 28  Observational coastal physical oceanography an...
# 29                     Ocean Observatories Initiative
# 30     Marine geology and geophysics, paleoseismology
# 31  Cycling of natural organic matter in the earth...
# 32  Coastal ocean carbon cycles, ocean acidificati...
# 33  Nearshore remote sensing, surface wave transfo...
# 34  Marine geography, natural resource management ...
# 35                                   Sea ice dynamics
# 36  Dissolved gases, isotope biogeochemistry, mari...
# 37    Seascape ecology, remote sensing, global change
# 38                      Coastal physical oceanography
# 39  Marine pelagic microorganisms, biogeochemical ...
# 40  Stable isotopes & trace metals in paleoceanogr...
# 41  Turbulence dynamics, small-scale ocean physics...
# 42             Physics of turbulence and ocean mixing
# 43  Air-sea interactions, satellite meteorology an...
# 44  Near-shore circulation modeling, data assimila...
# 45  Physics of mixing processes (i.e. turbulence) ...
# 46  Benthic biogeochemistry, chemical sensor devel...
# 47  Coastal geomorphology, coastal hazards, nearsh...
# 48  Climate change, ocean biogeochemical cycles, i...
# 49  Physical processes in coastal ocean, Autonomou...
# 50  Small-scale ocean dynamics, such as turbulent ...
# 51  Turbulence in geophysical flows, thermohaline ...
# 52  The main pathways in marine ecosystems, couple...
# 53  Sediments magnetism, paleomagnetism, environme...
# 54  Microbe-metazoan Interactions, deep-sea and po...
# 55  Application of foraminiferal stable isotopes i...
# 56  Ocean acidification effects on bivalves, benth...
# 57  Land-ocean connectivity, sediment and carbon f...
# 58  Physics of the nearshore coastal ocean includi...
#
#                                                   URL  \
# 0   https://www.soest.hawaii.edu/oceanography/prof...
# 1   https://www.soest.hawaii.edu/oceanography/prof...
# 2   https://www.soest.hawaii.edu/oceanography/prof...
# 3   https://www.soest.hawaii.edu/oceanography/prof...
# 4   https://www.soest.hawaii.edu/oceanography/prof...
# 5   https://www.soest.hawaii.edu/oceanography/prof...
# 6   https://www.soest.hawaii.edu/oceanography/prof...
# 7   https://www.soest.hawaii.edu/oceanography/prof...
# 8   https://www.soest.hawaii.edu/oceanography/prof...
# 9   https://www.soest.hawaii.edu/oceanography/prof...
# 10  https://www.soest.hawaii.edu/oceanography/prof...
# 11  https://www.soest.hawaii.edu/oceanography/prof...
# 12  https://www.soest.hawaii.edu/oceanography/prof...
# 13  https://www.soest.hawaii.edu/oceanography/prof...
# 14  https://www.soest.hawaii.edu/oceanography/prof...
# 15  https://www.soest.hawaii.edu/oceanography/prof...
# 16  https://www.soest.hawaii.edu/oceanography/prof...
# 17  https://www.soest.hawaii.edu/oceanography/prof...
# 18  https://www.soest.hawaii.edu/oceanography/prof...
# 19                                 /people/jack-barth
# 20                                /people/kim-bernard
# 21                               /people/rene-boiteau
# 22                          /people/lorenzo-ciannelli
# 23                          /people/frederick-colwell
# 24                                /people/byron-crump
# 25                            /people/simon-de-szoeke
# 26                               /people/edward-dever
# 27                      /people/jennifer-fehrenbacher
# 28                            /people/melanie-fewings
# 29                              /people/jonathan-fram
# 30                           /people/chris-goldfinger
# 31                                /people/miguel-goni
# 32                                /people/burke-hales
# 33                             /people/merrick-haller
# 34                              /people/michael-harte
# 35                         /people/jennifer-hutchings
# 36                             /people/lauren-juranek
# 37                            /people/maria-kavanaugh
# 38                              /people/james-lerczak
# 39                           /people/ricardo-letelier
# 40                             /people/jennifer-mckay
# 41                                 /people/james-moum
# 42                              /people/jonathan-nash
# 43                               /people/larry-oneill
# 44                          /people/tuba-ozkan-haller
# 45                             /people/brodie-pearson
# 46                              /people/clare-reimers
# 47                             /people/peter-ruggiero
# 48                         /people/andreas-schmittner
# 49                            /people/r-kipp-shearman
# 50                              /people/emily-shroyer
# 51                              /people/william-smyth
# 52                               /people/yvette-spitz
# 53                              /people/joseph-stoner
# 54                             /people/andrew-thurber
# 55                            /people/maureen-walczak
# 56                          /people/george-waldbusser
# 57                          /people/robert-wheatcroft
# 58                             /people/gregory-wilson
#
#                       Institution_Name
# 0   ['University of Hawaiʻi at Mānoa']
# 1   ['University of Hawaiʻi at Mānoa']
# 2   ['University of Hawaiʻi at Mānoa']
# 3   ['University of Hawaiʻi at Mānoa']
# 4   ['University of Hawaiʻi at Mānoa']
# 5   ['University of Hawaiʻi at Mānoa']
# 6   ['University of Hawaiʻi at Mānoa']
# 7   ['University of Hawaiʻi at Mānoa']
# 8   ['University of Hawaiʻi at Mānoa']
# 9   ['University of Hawaiʻi at Mānoa']
# 10  ['University of Hawaiʻi at Mānoa']
# 11  ['University of Hawaiʻi at Mānoa']
# 12  ['University of Hawaiʻi at Mānoa']
# 13  ['University of Hawaiʻi at Mānoa']
# 14  ['University of Hawaiʻi at Mānoa']
# 15  ['University of Hawaiʻi at Mānoa']
# 16  ['University of Hawaiʻi at Mānoa']
# 17  ['University of Hawaiʻi at Mānoa']
# 18  ['University of Hawaiʻi at Mānoa']
# 19         ['Oregon State University']
# 20         ['Oregon State University']
# 21         ['Oregon State University']
# 22         ['Oregon State University']
# 23         ['Oregon State University']
# 24         ['Oregon State University']
# 25         ['Oregon State University']
# 26         ['Oregon State University']
# 27         ['Oregon State University']
# 28         ['Oregon State University']
# 29         ['Oregon State University']
# 30         ['Oregon State University']
# 31         ['Oregon State University']
# 32         ['Oregon State University']
# 33         ['Oregon State University']
# 34         ['Oregon State University']
# 35         ['Oregon State University']
# 36         ['Oregon State University']
# 37         ['Oregon State University']
# 38         ['Oregon State University']
# 39         ['Oregon State University']
# 40         ['Oregon State University']
# 41         ['Oregon State University']
# 42         ['Oregon State University']
# 43         ['Oregon State University']
# 44         ['Oregon State University']
# 45         ['Oregon State University']
# 46         ['Oregon State University']
# 47         ['Oregon State University']
# 48         ['Oregon State University']
# 49         ['Oregon State University']
# 50         ['Oregon State University']
# 51         ['Oregon State University']
# 52         ['Oregon State University']
# 53         ['Oregon State University']
# 54         ['Oregon State University']
# 55         ['Oregon State University']
# 56         ['Oregon State University']
# 57         ['Oregon State University']
# 58         ['Oregon State University']
